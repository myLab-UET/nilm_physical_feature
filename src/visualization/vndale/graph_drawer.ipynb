# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import cm

vndale_data_dict = {
    # "RF training": [0.900, 0.943, 0.994, 0.999, 0.999, 0.999],
    "RF test": [0.899, 0.929, 0.977, 0.998, 0.998, 0.999],
    # "XGBoost training": [0.894, 0.925, 0.971, 0.995, 0.995, 0.998],
    "XGBoost test": [0.894, 0.926, 0.971, 0.995, 0.995, 0.997],
    # "MLP training": [0.899, 0.931, 0.978, 0.997, 0.998, 0.999],
    "MLP test": [0.894, 0.926, 0.971, 0.995, 0.995, 0.997]
}
feature_set = ["Irms", "P", "Irms - P", "Irms - P \n- $\\bar{pf}$", "Irms - P \n- $\\bar{pf}$ - S", "Irms - P \n- $\\bar{pf}$ - S - Q"]

# Enable LaTeX rendering
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman']
plt.rcParams.update({'font.size': 18})

# Define the markers
markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'd', '|', '_']

# Create a new figure and axis
fig, ax = plt.subplots()
fig.set_size_inches(14, 7)

# Get the viridis colormap
# colors = ['#800000', '#FF0000', '#008000', '#90EE90', '#191970', '#87CEEB']
colors = ['#800000', '#008000', '#191970']
styles = ['-', '--', ':']
viridis = lambda i: colors[i % len(colors)]

# Plot each accuracy metric from data_dict on the existing ax
for i, (metric, values) in enumerate(vndale_data_dict.items()):
    ax.plot(
        feature_set,
        values,
        marker=markers[i % len(markers)],
        color=viridis(i),
        label=metric
    )

# Place the legend outside the plot and set the font size
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=16, title="Models - Dataset", frameon=False)
ax.set_xlabel("Feature set", fontsize=22)
ax.set_ylabel("Test accuracy", fontsize=22)
ax.set_title("iAWE Test accuracies vs Feature set")
# Add styles to the plot lines
for line, style in zip(ax.get_lines(), styles):
    line.set_linestyle(style)
ax.yaxis.grid(True)

plt.tight_layout()
plt.subplots_adjust(right=0.75)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import cm

vndale_data_dict = {
    # "RF training": [0.439, 0.393, 0.815, 0.989, 0.991, 0.992],
    "RF test": [0.438, 0.391, 0.809, 0.939, 0.940, 0.931],
    # "XGBoost training": [0.396, 0.348, 0.707, 0.943, 0.949, 0.958],
    "XGBoost test": [0.401, 0.359, 0.718, 0.903, 0.908, 0.911],
    # "MLP training": [0.439, 0.384, 0.803, 0.971, 0.965, 0.969],
    "MLP test": [0.438, 0.392, 0.801, 0.943, 0.937, 0.941]
}
feature_set = ["Irms", "P", "Irms - P", "Irms - P \n- $\\bar{pf}$", "Irms - P \n- $\\bar{pf}$ - S", "Irms - P \n- $\\bar{pf}$ - S - Q"]


# Define the markers
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams.update({'font.size': 18})

markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'd', '|', '_']

# Create a new figure and axis
fig, ax = plt.subplots()
fig.set_size_inches(14, 7)

# Get the viridis colormap
# colors = ['#800000', '#FF0000', '#008000', '#90EE90', '#191970', '#87CEEB']
colors = ['#800000', '#008000', '#191970']
styles = ['-', '--', ':']
viridis = lambda i: colors[i % len(colors)]

# Plot each accuracy metric from data_dict on the existing ax
for i, (metric, values) in enumerate(vndale_data_dict.items()):
    ax.plot(
        feature_set,
        values,
        marker=markers[i % len(markers)],
        color=viridis(i),
        label=metric
    )

# Place the legend outside the plot and set the font size
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=16, title="Models - Dataset", frameon=False)
ax.set_xlabel("Feature Set", fontsize=19)
ax.set_ylabel("Validation accuracy", fontsize=19)
ax.set_title("VNDALE Validation accuracies vs Feature Set")
# Add styles to the plot lines
for line, style in zip(ax.get_lines(), styles):
    line.set_linestyle(style)
ax.yaxis.grid(True)

plt.tight_layout()
plt.subplots_adjust(right=0.75)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import cm

rae_data_dict = {
    # "RF training": [0.658, 0.738, 0.927, 0.979, 0.979, 0.999],
    "RF test": [0.659, 0.739, 0.927, 0.978, 0.978, 0.998],
    # "XGBoost training": [0.653, 0.728, 0.911, 0.973, 0.975, 0.998],
    "XGBoost test": [0.654, 0.730, 0.911, 0.973, 0.975, 0.998],
    # "MLP training": [0.659, 0.738, 0.926, 0.977, 0.977, 0.999],
    "MLP test": [0.659, 0.738, 0.926, 0.977, 0.977, 0.998]
}

feature_set = ["Irms", "P", "Irms - P", "Irms - P \n- $\\bar{pf}$", "Irms - P \n- $\\bar{pf}$ - S", "Irms - P \n- $\\bar{pf}$ - S - Q"]

# Define the markers
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams.update({'font.size': 18})

markers = ['o', 's', 'D', '^', 'v', '<', '>', 'p', '*', 'h', 'H', '+', 'x', 'd', '|', '_']

# Create a new figure and axis
fig, ax = plt.subplots()
fig.set_size_inches(14, 7)

# Get the viridis colormap
# colors = ['#800000', '#FF0000', '#008000', '#90EE90', '#191970', '#87CEEB']
colors = ['#800000', '#008000', '#191970']
styles = ['-', '--', ':']
viridis = lambda i: colors[i % len(colors)]

# Plot each accuracy metric from data_dict on the existing ax
for i, (metric, values) in enumerate(rae_data_dict.items()):
    ax.plot(
        feature_set,
        values,
        marker=markers[i % len(markers)],
        color=viridis(i),
        label=metric
    )

# Place the legend outside the plot and set the font size
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=16, title="Models - Dataset", frameon=False)
ax.set_xlabel("Feature Set", fontsize=19)
ax.set_ylabel("Test accuracy", fontsize=19)
ax.set_title("RAE Test accuracies vs Feature Set")
# Add styles to the plot lines
for line, style in zip(ax.get_lines(), styles):
    line.set_linestyle(style)
ax.yaxis.grid(True)

plt.tight_layout()
plt.subplots_adjust(right=0.75)
plt.show()
