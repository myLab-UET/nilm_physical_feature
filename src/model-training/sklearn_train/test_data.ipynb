# %%
from nilm_dao import get_vndale1_data

# %%
train_df = get_vndale1_data("train", 1800)
# Out:
# Getting train data - window size: 1800: 100%|██████████| 128/128 [02:34<00:00,  1.21s/it]

# %%
train_df
# Out:
# shape: (432_000, 11)
# ┌─────────────┬───────────┬─────────────┬───────────┬───┬───────────┬──────────┬───────────┬───────┐
# │ Time        ┆ In        ┆ Un          ┆ PF_n      ┆ … ┆ P         ┆ Q        ┆ S         ┆ Label │
# │ ---         ┆ ---       ┆ ---         ┆ ---       ┆   ┆ ---       ┆ ---      ┆ ---       ┆ ---   │
# │ str         ┆ f64       ┆ f64         ┆ f64       ┆   ┆ f64       ┆ f64      ┆ f64       ┆ i64   │
# ╞═════════════╪═══════════╪═════════════╪═══════════╪═══╪═══════════╪══════════╪═══════════╪═══════╡
# │ 2024-01-17_ ┆ -0.041702 ┆ -177.508484 ┆ 74.907135 ┆ … ┆ 15.986243 ┆ 4.485687 ┆ 18.385653 ┆ 54    │
# │ 12-04-13    ┆           ┆             ┆           ┆   ┆           ┆          ┆           ┆       │
# │ 2024-01-17_ ┆ -0.115716 ┆ -230.873169 ┆ 74.907135 ┆ … ┆ 16.359095 ┆ 4.498    ┆ 18.761965 ┆ 54    │
# │ 12-04-13    ┆           ┆             ┆           ┆   ┆           ┆          ┆           ┆       │
# ...
